# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
ds = pd.read_csv('compressed_data.csv')
# Out:
# C:\Users\sarthak\AppData\Local\Temp\ipykernel_29076\1472362603.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv('compressed_data.csv')

# %%
ds.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %% [markdown]
# # Clean the Dataset

# %%
ds.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
ds.isnull().mean()*100
# Out:
# id                                 0.000000
# NAME                               0.243667
# host id                            0.000000
# host_identity_verified             0.281679
# host name                          0.395715
# neighbourhood group                0.028265
# neighbourhood                      0.015595
# lat                                0.007797
# long                               0.007797
# country                            0.518524
# country code                       0.127682
# instant_bookable                   0.102340
# cancellation_policy                0.074075
# room type                          0.000000
# Construction year                  0.208579
# price                              0.240743
# service fee                        0.266084
# minimum nights                     0.398639
# number of reviews                  0.178364
# last review                       15.490404
# reviews per month                 15.476759
# ...

# %%
ds.shape
# Out:
# (102599, 26)

# %%
ds['last review'] = pd.to_datetime(ds['last review'], errors = 'coerce')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
ds.fillna({'reviews per month' : 0, 'last review' : ds['last review'].min()}, inplace = True)

# %%
ds.dropna(subset = ['NAME', 'host name'], inplace = True)

# %%
ds.isnull().sum()
# Out:
# id                                     0
# NAME                                   0
# host id                                0
# host_identity_verified               276
# host name                              0
# neighbourhood group                   26
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              526
# country code                         122
# instant_bookable                      96
# cancellation_policy                   70
# room type                              0
# Construction year                    200
# price                                239
# service fee                          268
# minimum nights                       403
# number of reviews                    182
# last review                            0
# reviews per month                      0
# review rate number                   314
# calculated host listings count       318
# ...

# %%
ds.drop(['license', 'house_rules'], axis =1, inplace = True)

# %%
ds['price'] = ds['price'].replace('[\$,]', '', regex =True).astype(float)
ds['service fee'] = ds['service fee'].replace('[\$,]', '', regex = True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\akash\AppData\Local\Temp\ipykernel_29076\270345741.py:1: SyntaxWarning: invalid escape sequence '\$'
#   ds['price'] = ds['price'].replace('[\$,]', '', regex =True).astype(float)
# C:\Users\akash\AppData\Local\Temp\ipykernel_29076\270345741.py:2: SyntaxWarning: invalid escape sequence '\$'
#   ds['service fee'] = ds['service fee'].replace('[\$,]', '', regex = True).astype(float)

# %%
ds.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... Construction year  price  \
# ...

# %%
ds.drop_duplicates(inplace =True)

# %%
ds.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.014100e+05  1.014100e+05  101402.000000  101402.000000
# mean   2.920959e+07  4.926155e+10      40.728082     -73.949663
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.507574e+07  2.459183e+10      40.688730     -73.982570
# 50%    2.922911e+07  4.912069e+10      40.722300     -73.954440
# 75%    4.328308e+07  7.399747e+10      40.762750     -73.932340
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
# std    1.626820e+07  2.853703e+10       0.055850       0.049474
#
#        Construction year          price    service fee  minimum nights  \
# count      101210.000000  101171.000000  101142.000000   101016.000000
# mean         2012.486908     625.381008     125.043998        8.113744
# min          2003.000000      50.000000      10.000000    -1223.000000
# 25%          2007.000000     340.000000      68.000000        2.000000
# ...

# %%
ds.isnull().sum()
# Out:
# id                                  0
# NAME                                0
# host id                             0
# host_identity_verified            276
# host name                           0
# neighbourhood group                26
# neighbourhood                      16
# lat                                 8
# long                                8
# country                           526
# country code                      122
# instant_bookable                   96
# cancellation_policy                70
# room type                           0
# Construction year                 200
# price                             239
# service fee                       268
# minimum nights                    394
# number of reviews                 182
# last review                         0
# reviews per month                   0
# review rate number                307
# calculated host listings count    318
# availability 365                  420
# dtype: int64

# %%
ds.fillna({'price' : ds['price'].mean()}, inplace = True)

# %%
ds.isnull().sum()
# Out:
# id                                  0
# NAME                                0
# host id                             0
# host_identity_verified            276
# host name                           0
# neighbourhood group                26
# neighbourhood                      16
# lat                                 8
# long                                8
# country                           526
# country code                      122
# instant_bookable                   96
# cancellation_policy                70
# room type                           0
# Construction year                 200
# price                               0
# service fee                       268
# minimum nights                    394
# number of reviews                 182
# last review                         0
# reviews per month                   0
# review rate number                307
# calculated host listings count    318
# availability 365                  420
# dtype: int64

# %%
ds.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 4               verified    Lyndon           Manhattan   East Harlem
# 5               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long        country  ... Construction year price service fee  \
# ...

# %% [markdown]
# # Q.1 -What is the distribution of listing prices?

# %%
plt.figure(figsize = (8,5))
sns.histplot(x = ds['price'], bins = 50, kde = True, color = 'red')
plt.title('Distributio of listing price')
plt.xlabel('Price in $')
plt.show()

# %% [markdown]
# The price histogram shows the even distribution of listing price ranges across different prices.
# There is a specific consideration of listing price in any particular price range
# The KDE line helps us to visualise the graph more effectively

# %% [markdown]
# # Q2 How fiffernet room type are distributed

# %%
plt.figure(figsize = (8,5))
sns.countplot(x = ds['room type'], color = 'blue', order = ds['room type'].value_counts().index)
plt.title('Room type disribution')
plt.xlabel('Count')
plt.ylabel('Room Type')
plt.show()

# %% [markdown]
# According to the distribution, more people like to book an apartment room type.
# and the second preference is a private room
# Shared room and hotel room are significantly less prefered.

# %% [markdown]
# # Q3. How are listings distributed across different neighborhoods?

# %%
plt.figure(figsize = (8,5))
sns.countplot(y = ds['neighbourhood group'], color = 'green', order = ds['neighbourhood group'].value_counts().index)
plt.title('distributedion across different neighborhoods')
plt.xlabel('Count')
plt.ylabel('neighborhoods')
plt.show()

# %% [markdown]
# # Q4. Relationship between price and room type

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = 'room type', y = 'price', hue = 'room type', data = ds, palette = 'Set1')
plt.title('Price and rom type distribution')
plt.ylabel('Price in $')
plt.xlabel('Room Type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
